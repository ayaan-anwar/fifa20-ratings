# %%
# !ls
# Out:
# FIFA_20.csv  fifa20-ratings.ipynb  README.md

# %%
import pandas as pd
import numpy as np

# %%
fifa = pd.read_csv('FIFA_20.csv')

# %%
fifa.head()
# Out:
#    overall               name nationality                 club    position  \
# 0       94           L. Messi   Argentina         FC Barcelona  Midfielder
# 1       93  Cristiano Ronaldo    Portugal             Juventus  Midfielder
# 2       92          Neymar Jr      Brazil  Paris Saint-Germain  Midfielder
# 3       91          E. Hazard     Belgium          Real Madrid  Midfielder
# 4       91       K. De Bruyne     Belgium      Manchester City  Midfielder
#
#   preferred_foot work_rate  jersey_number  wage_eur  international_reputation  \
# 0           Left    Medium             10    565000                         5
# 1          Right      High              7    405000                         5
# 2          Right      High             10    290000                         5
# 3          Right      High              7    470000                         4
# 4          Right      High             17    370000                         4
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(20,20))
sns.heatmap(fifa.corr(), annot=True)

# %%
fifa.columns
# Out:
# Index(['overall', 'name', 'nationality', 'club', 'position', 'preferred_foot',
#        'work_rate', 'jersey_number', 'wage_eur', 'international_reputation',
#        'weak_foot', 'skill_moves', 'age', 'height_cm', 'weight_kg', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'physic', 'finishing',
#        'fk_accuracy', 'acceleration', 'agility', 'stamina', 'penalties',
#        'composure', 'standing_tackle', 'sliding_tackle'],
#       dtype='object')

# %%
fifa.dtypes
# Out:
# overall                      int64
# name                        object
# nationality                 object
# club                        object
# position                    object
# preferred_foot              object
# work_rate                   object
# jersey_number                int64
# wage_eur                     int64
# international_reputation     int64
# weak_foot                    int64
# skill_moves                  int64
# age                          int64
# height_cm                    int64
# weight_kg                    int64
# pace                         int64
# shooting                     int64
# passing                      int64
# dribbling                    int64
# defending                    int64
# physic                       int64
# finishing                    int64
# fk_accuracy                  int64
# acceleration                 int64
# agility                      int64
# stamina                      int64
# penalties                    int64
# ...

# %% [markdown]
# ## Overall Rating v/s Different Skill Levels

# %%
skill_cols = [col for col in fifa.columns if col not in ('name', 'nationality', 'club', 'overall', 'position', 
                                                         'preferred_foot', 'work_rate', 'jersey_number', 
                                                         'international_reputation', 'weak_foot', 'skill_moves', 
                                                         'wage_eur', 'age', 'height_cm', 'weight_kg')]

# jersey_number, international_reputation, weak_foot, skill_moves are categorical
# wage_eur, age, height_cm, weight_kg will need different scales for the axes

plt.figure(figsize=(20, 80))

i = 1
for col in skill_cols:
    plt.subplot(8, 2, i, title=f'overall v/s {col}')
    plt.ylim(0, 100)
    plt.xlim(0, 100)
    sns.scatterplot(data=fifa, y='overall', x=col)
    i = i + 1
