# %%
# !ls
# Out:
# 731483_1269688_bundle_archive.zip  FIFA_20.csv	Untitled.ipynb

# %%
import pandas as pd
import numpy as np

# %%
fifa = pd.read_csv('FIFA_20.csv')

# %%
fifa.head()
# Out:
#    overall               name nationality                 club    position  \
# 0       94           L. Messi   Argentina         FC Barcelona  Midfielder
# 1       93  Cristiano Ronaldo    Portugal             Juventus  Midfielder
# 2       92          Neymar Jr      Brazil  Paris Saint-Germain  Midfielder
# 3       91          E. Hazard     Belgium          Real Madrid  Midfielder
# 4       91       K. De Bruyne     Belgium      Manchester City  Midfielder
#
#   preferred_foot work_rate  jersey_number  wage_eur  international_reputation  \
# 0           Left    Medium             10    565000                         5
# 1          Right      High              7    405000                         5
# 2          Right      High             10    290000                         5
# 3          Right      High              7    470000                         4
# 4          Right      High             17    370000                         4
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
fifa.columns
# Out:
# Index(['overall', 'name', 'nationality', 'club', 'position', 'preferred_foot',
#        'work_rate', 'jersey_number', 'wage_eur', 'international_reputation',
#        'weak_foot', 'skill_moves', 'age', 'height_cm', 'weight_kg', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'physic', 'finishing',
#        'fk_accuracy', 'acceleration', 'agility', 'stamina', 'penalties',
#        'composure', 'standing_tackle', 'sliding_tackle'],
#       dtype='object')

# %%
fifa.dtypes
# Out:
# overall                      int64
# name                        object
# nationality                 object
# club                        object
# position                    object
# preferred_foot              object
# work_rate                   object
# jersey_number                int64
# wage_eur                     int64
# international_reputation     int64
# weak_foot                    int64
# skill_moves                  int64
# age                          int64
# height_cm                    int64
# weight_kg                    int64
# pace                         int64
# shooting                     int64
# passing                      int64
# dribbling                    int64
# defending                    int64
# physic                       int64
# finishing                    int64
# fk_accuracy                  int64
# acceleration                 int64
# agility                      int64
# stamina                      int64
# penalties                    int64
# ...

# %%
sns.boxplot(data=fifa, x='work_rate', y='overall')

# %%
plt.figure(figsize=(20,20))
sns.heatmap(fifa.corr(), annot=True)

# %%
sns.scatterplot(data=fifa, x='work_rate', y='overall')

# %%
fifa.columns
# Out:
# Index(['overall', 'name', 'nationality', 'club', 'position', 'preferred_foot',
#        'work_rate', 'jersey_number', 'wage_eur', 'international_reputation',
#        'weak_foot', 'skill_moves', 'age', 'height_cm', 'weight_kg', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'physic', 'finishing',
#        'fk_accuracy', 'acceleration', 'agility', 'stamina', 'penalties',
#        'composure', 'standing_tackle', 'sliding_tackle'],
#       dtype='object')

# %%
fifa.dtypes
# Out:
# overall                      int64
# name                        object
# nationality                 object
# club                        object
# position                    object
# preferred_foot              object
# work_rate                   object
# jersey_number                int64
# wage_eur                     int64
# international_reputation     int64
# weak_foot                    int64
# skill_moves                  int64
# age                          int64
# height_cm                    int64
# weight_kg                    int64
# pace                         int64
# shooting                     int64
# passing                      int64
# dribbling                    int64
# defending                    int64
# physic                       int64
# finishing                    int64
# fk_accuracy                  int64
# acceleration                 int64
# agility                      int64
# stamina                      int64
# penalties                    int64
# ...

# %%
#drop
